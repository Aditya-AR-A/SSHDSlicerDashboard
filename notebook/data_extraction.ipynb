# %% [markdown]
# # Data Extraction from the http://120.79.192.226/ for Extraction and vuisualisation

# %%
import os
import sys
import logging
from pathlib import Path
from dotenv import load_dotenv
from IPython.display import IFrame, display

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as ps
import plotly.graph_objects as go
import plotly.io as pio

import requests
from bs4 import  BeautifulSoup
from urllib.parse import urljoin

import json

# %% [markdown]
# ## Auxilary Data

# %%
print(os.getcwd())
# Out:
# /home/aditya/DEV/scorer/notebook

# %%
load_dotenv("../.env")
# Out:
# True

# %% [markdown]
# ## CONSTANTS

# %%
# Base target dashboard link
BASE_LINK = os.getenv("DASHBOARD_URL")

# Admin Credentials
ADMIN_ID = os.getenv("ADMIN_USERNAME")
ADMIN_PASSWORD = os.getenv("ADMIN_PASSWORD")

# Local Timezone
TIMEZONE = os.getenv("TIMEZONE")

# Database URL
DATABASE_URL = os.getenv("DATABASE_URL")

# %% [markdown]
# ## Scraping

# %% [markdown]
# ### Functions

# %%
def create_session():
    try:
        session = requests.Session()
        print(">>> Session Created")
    except:
        print(">>> Session not Created")

    return session

# %%
def
