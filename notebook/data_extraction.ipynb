# %% [markdown]
# # Data Extraction from the http://120.79.192.226/ for Extraction and vuisualisation

# %%
import os
import sys
from pathlib import Path
import logging
import dotenv

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as ps
import plotly.graph_objects as go
import plotly.io as pio

import requests
from bs4 import  BeautifulSoup

# %% [markdown]
# ## Auxilary Data

# %%
dotenv.load_dotenv()
# Out:
# True

# %% [markdown]
# ## CONSTANTS

# %%
BASE_LINK = "http://120.79.192.226/"
# Out:
# Resolved 153 packages in 4.92s
#    Building slicing-dashboard @ file:///home/aditya/DEV/scorer         ⠋ Preparing packages... (0/0)
#       Built slicing-dashboard @ file:///home/aditya/DEV/scorer
# Prepared 1 package in 27ms
# Uninstalled 1 package in 5ms
# Installed 8 packages in 98ms
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + fonttools==4.63.0
#  + kiwisolver==1.5.0
#  + matplotlib==3.11.1
#  + pillow==12.3.0
#  + pyparsing==3.3.2
#  ~ slicing-dashboard==0.1.0 (from file:///home/aditya/DEV/scorer)
